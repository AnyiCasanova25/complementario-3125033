# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# Cargar el archivo CSV modificado
archivo_csv = "lenguajes_mas_usados.csv"
df = pd.read_csv(archivo_csv)

# Filtrar por un año específico, en este caso 2024
df_filtered = df[df["Año"] == 2024]

# Ordenar por porcentaje de uso descendente y reasignar rankings
df_filtered = df_filtered.sort_values(by="Porcentaje", ascending=False).reset_index(drop=True)
df_filtered["Ranking"] = np.arange(1, len(df_filtered) + 1)

# Separar variables independiente (Ranking) y dependiente (Porcentaje)
X = df_filtered[["Ranking"]].values  # Variable independiente
y = df_filtered["Porcentaje"].values  # Variable dependiente

# Crear y ajustar el modelo de regresión lineal
model = LinearRegression()
model.fit(X, y)

# Generar predicciones
y_pred = model.predict(X)

# Mostrar los coeficientes del modelo
print("Pendiente (coeficiente):", model.coef_[0])
print("Intercepto:", model.intercept_)

# Graficar los datos reales y la regresión lineal
plt.figure(figsize=(12, 6))
plt.scatter(df_filtered["Ranking"], df_filtered["Porcentaje"], color="blue", label="Datos reales")
plt.plot(df_filtered["Ranking"], y_pred, color="red", label="Regresión Lineal")

# Etiquetas y título
plt.xlabel("Ranking de Lenguajes")
plt.ylabel("Porcentaje de Uso (%)")
plt.title("Regresión Lineal sobre Popularidad de Lenguajes de Programación (2024)")
plt.legend()
plt.grid(True)
plt.tight_layout()

# Mostrar el gráfico
plt.show()
# Out:
# Pendiente (coeficiente): -2.482727272727274
# Intercepto: 27.24181818181819
